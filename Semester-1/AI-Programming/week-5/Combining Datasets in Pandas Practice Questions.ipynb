# %% [markdown]
# # Combining Datasets in Pandas Coding Practice Questions

# %% [markdown]
# 1. Create two DataFrames `df1` and `df2` with the following data:
#    ```
#    df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
#                       'B': ['B0', 'B1', 'B2', 'B3'],
#                       'key': ['K0', 'K1', 'K2', 'K3']})
#
#    df2 = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C3'],
#                       'D': ['D0', 'D1', 'D2', 'D3'],
#                       'key': ['K0', 'K1', 'K2', 'K3']})
#    ```
#    Display the DataFrames.

# %%
import pandas as pd
import numpy as np

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                   'B': ['B0', 'B1', 'B2', 'B3'],
                   'key': ['K0', 'K1', 'K2', 'K3']})

df2 = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C3'],
                   'D': ['D0', 'D1', 'D2', 'D3'],
                   'key': ['K0', 'K1', 'K2', 'K3']})

# %%
df1
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3

# %%
df2
# Out:
#     C   D key
# 0  C0  D0  K0
# 1  C1  D1  K1
# 2  C2  D2  K2
# 3  C3  D3  K3

# %% [markdown]
# 2. Merge `df1` and `df2` on the 'key' column using an inner join. Display the result.

# %%
pd.merge(df1, df2, on='key', how='inner')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %% [markdown]
# 3. Merge `df1` and `df2` on the 'key' column using an outer join. Display the result.

# %%
pd.merge(df1, df2, on='key', how='outer')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %% [markdown]
# 4. Merge `df1` and `df2` on the 'key' column using a left join with `df1` as the left DataFrame. Display the result.

# %%
pd.merge(df1, df2, on='key', how='left')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %% [markdown]
# 5. Merge `df1` and `df2` on the 'key' column using a right join with `df2` as the right DataFrame. Display the result.

# %%
pd.merge(df1, df2, on='key', how='right')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %% [markdown]
# 6. Concatenate `df1` and `df2` along the rows. Display the result.

# %%
pd.concat([df1, df2])
# Out:
#      A    B key    C    D
# 0   A0   B0  K0  NaN  NaN
# 1   A1   B1  K1  NaN  NaN
# 2   A2   B2  K2  NaN  NaN
# 3   A3   B3  K3  NaN  NaN
# 0  NaN  NaN  K0   C0   D0
# 1  NaN  NaN  K1   C1   D1
# 2  NaN  NaN  K2   C2   D2
# 3  NaN  NaN  K3   C3   D3

# %% [markdown]
# 7. Concatenate `df1` and `df2` along the columns. Display the result.

# %%
pd.concat([df1, df2], axis=1)
# Out:
#     A   B key   C   D key
# 0  A0  B0  K0  C0  D0  K0
# 1  A1  B1  K1  C1  D1  K1
# 2  A2  B2  K2  C2  D2  K2
# 3  A3  B3  K3  C3  D3  K3

# %% [markdown]
# 8. Use the `append` method to add `df2` to `df1`. Display the result.

# %%
df1.append(df2)
# Out:
# <ipython-input-20-8ab0723181fb>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#      A    B key    C    D
# 0   A0   B0  K0  NaN  NaN
# 1   A1   B1  K1  NaN  NaN
# 2   A2   B2  K2  NaN  NaN
# 3   A3   B3  K3  NaN  NaN
# 0  NaN  NaN  K0   C0   D0
# 1  NaN  NaN  K1   C1   D1
# 2  NaN  NaN  K2   C2   D2
# 3  NaN  NaN  K3   C3   D3

# %% [markdown]
# 9. Create a MultiIndex DataFrame `df3` using the following data:
#    ```
#    df3 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
#                       'B': ['B4', 'B5', 'B6', 'B7'],
#                       'key': ['K0', 'K1', 'K2', 'K3'],
#                       'key2': ['K4', 'K5', 'K6', 'K7']})
#    ```
#    Display the DataFrame.

# %%
df3 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                   'B': ['B4', 'B5', 'B6', 'B7'],
                   'key': ['K0', 'K1', 'K2', 'K3'],
                   'key2': ['K4', 'K5', 'K6', 'K7']})
df3
# Out:
#     A   B key key2
# 0  A4  B4  K0   K4
# 1  A5  B5  K1   K5
# 2  A6  B6  K2   K6
# 3  A7  B7  K3   K7

# %% [markdown]
# 10. Merge `df1` and `df3` using multiple keys: 'key' and 'key2'. Display the result.

# %%
# Add 'key2' column to df1
df1['key2'] = ['K4', 'K5', 'K6', 'K7']

pd.merge(df1, df3, on=['key', 'key2'])
# Out:
#   A_x B_x key key2 A_y B_y
# 0  A0  B0  K0   K4  A4  B4
# 1  A1  B1  K1   K5  A5  B5
# 2  A2  B2  K2   K6  A6  B6
# 3  A3  B3  K3   K7  A7  B7

# %% [markdown]
# 11. Use the `join` method to combine `df1` and `df2` using the 'key' column. Display the result.

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                   'B': ['B0', 'B1', 'B2', 'B3'],
                   'key': ['K0', 'K1', 'K2', 'K3']})
result = df1.join(df2.set_index('key'), on='key')
result
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K2  C2  D2
# 3  A3  B3  K3  C3  D3

# %% [markdown]
# 12. Use the `pivot` method to reshape `df1` such that 'A' and 'B' columns become columns and the 'key' column becomes the index. Display the result.

# %%
df1.pivot(index='key', columns=['A', 'B'], values=['A', 'B'])
# Out:
#        A                   B
# A     A0   A1   A2   A3   A0   A1   A2   A3
# B     B0   B1   B2   B3   B0   B1   B2   B3
# key
# K0    A0  NaN  NaN  NaN   B0  NaN  NaN  NaN
# K1   NaN   A1  NaN  NaN  NaN   B1  NaN  NaN
# K2   NaN  NaN   A2  NaN  NaN  NaN   B2  NaN
# K3   NaN  NaN  NaN   A3  NaN  NaN  NaN   B3

# %%
pivoted_df = df1.pivot(index='key', columns='A', values='B')
pivoted_df
# Out:
# A     A0   A1   A2   A3
# key
# K0    B0  NaN  NaN  NaN
# K1   NaN   B1  NaN  NaN
# K2   NaN  NaN   B2  NaN
# K3   NaN  NaN  NaN   B3

# %% [markdown]
# 13. Create a pivot table from `df1` using the 'key' column as the index and 'A' as values. Display the result.

# %%
pivot_table_df = df1.pivot_table(index='key', values='A', aggfunc='first')
pivoted_df
# Out:
# B     B0   B1   B2   B3
# key
# K0    A0  NaN  NaN  NaN
# K1   NaN   A1  NaN  NaN
# K2   NaN  NaN   A2  NaN
# K3   NaN  NaN  NaN   A3

# %% [markdown]
# 14. Use the `melt` method to reshape `df1` to long format. Display the result.

# %%
df_melt = df1.melt(id_vars='key', value_vars=['A', 'B'])
df_melt
# Out:
#   key variable value
# 0  K0        A    A0
# 1  K1        A    A1
# 2  K2        A    A2
# 3  K3        A    A3
# 4  K0        B    B0
# 5  K1        B    B1
# 6  K2        B    B2
# 7  K3        B    B3

# %% [markdown]
# 15. Use the `stack` method to reshape `df1`. Display the result.

# %%
stacked_df = df1.stack()
stacked_df
# Out:
# 0  A      A0
#    B      B0
#    key    K0
# 1  A      A1
#    B      B1
#    key    K1
# 2  A      A2
#    B      B2
#    key    K2
# 3  A      A3
#    B      B3
#    key    K3
# dtype: object

# %% [markdown]
# 16. Use the `unstack` method to reshape the stacked `df1`. Display the result.

# %%
print(df1)
unstacked_df = stacked_df.unstack()
unstacked_df
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K2
# 3  A3  B3  K3

# %% [markdown]
# 17. Use the `crosstab` method to compute a cross-tabulation of the 'A' and 'B' columns from `df1`. Display the result.

# %%
crosstabed_df = pd.crosstab(df1['A'], df1['B'])
crosstabed_df
# Out:
# B   B0  B1  B2  B3
# A
# A0   1   0   0   0
# A1   0   1   0   0
# A2   0   0   1   0
# A3   0   0   0   1

# %% [markdown]
# 18. Use the `pivot_table` method to create a pivot table from `df1` using 'A' as values and 'key' as the index. Display the result.

# %%
df1.pivot_table(index='key', values='A', aggfunc=[np.mean, sum])
# Out:
# <ipython-input-69-c3536cb93f63>:1: FutureWarning: The operation <function mean at 0x7d8734d38550> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df1.pivot_table(index='key', values='A', aggfunc=[np.mean, sum])
#     sum
#       A
# key
# K0   A0
# K1   A1
# K2   A2
# K3   A3

# %% [markdown]
# 19. Use the `groupby` method to group `df1` by the 'key' column and compute the mean of the 'A' column. Display the result.

# %%
df1['A'] = [0, 1, 2, 3]
df1
# Out:
#    A   B key
# 0  0  B0  K0
# 1  1  B1  K1
# 2  2  B2  K2
# 3  3  B3  K3

# %%
df1.groupby(by='key')['A'].mean()
# Out:
# key
# K0    0.0
# K1    1.0
# K2    2.0
# K3    3.0
# Name: A, dtype: float64

# %% [markdown]
# 20. Use the `agg` method to compute multiple aggregations on `df1`: mean of 'A' and sum of 'B'. Display the result.

# %%
df1['B'] = [0, 1, 2, 3]
df1
# Out:
#    A  B key
# 0  0  0  K0
# 1  1  1  K1
# 2  2  2  K2
# 3  3  3  K3

# %%
df1.agg({'A': 'mean', 'B': 'sum'})
# Out:
# A    1.5
# B    6.0
# dtype: float64

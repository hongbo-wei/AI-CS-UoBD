# %% [markdown]
# # Welcome to Programming for Data Science!
#
# ## Dr. Phil Smith

# %% [markdown]
# # What is Data Science?
#
# - It's difficult to nail down exactly what data science is...
# - What science doesn't involve data?
# - Cross-disciplinary set of skills
# - Important to industry and academia

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # So, what is Data Science??
#
# - Requires the skills of a **statistician**
# - and the skills of a **computer scientist**
# - but perhaps most importantly, **domain expertise**

# %% [markdown]
# ![image.png](attachment:image.png)
# https://www.tableau.com/data-insights/us-election-2020

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What's this course for?
#
# - Enable you to program and to use programming as a tool for data-intensive and computational science
# - Help you become confident using Python's data science stack libraries
# - Help you to become confident in both manipulating and gaining insight from data programmatically

# %% [markdown]
# # Why Python?
#
# - First class tool for scientific computing tasks.
#     - e.g For the analysis and visualisation of large datasets.
# - Nice syntax.
# - A large and active eco-system of third-party packages.

# %% [markdown]
# # Course Outline
#
# - During this module you will primarily learn about the following data science stack libraries:
#     - IPython and Jupyter Notebooks
#     - NumPy
#     - Pandas
#     - Scikit-learn
#     - Matplotlib & Seaborn

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hexbin(x, y, gridsize=20)

ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.show()

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
X = [[ 1,  2,  3],  # 2 samples, 3 features
     [11, 12, 13]]
y = [0, 1]  # classes of each sample
clf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# predict classes of the training data

clf.predict(X)
# Out:
# array([0, 1])

# %%
# predict classes of new data

clf.predict([[4,5,6], [14, 15, 16]])
# Out:
# array([0, 1])

# %% [markdown]
# # Lectures
#
# - Tuesday 10am in Aston Webb WG5
# - Friday 11am in Watson LTA G23
#
# 1. Concept driven approach to data science
# 2. Code examples
# 3. Interactive lectures

# %% [markdown]
# # Lab sessions
#
# 1. Monday 9-11am - Focus on Python Fundamentals
# 2. Wednesday 11-1pm - Focus on worksheets or getting help with assignments

# %% [markdown]
# # Core Material
#
# - Python Data Science Handbook by Jake VanderPlas
# - https://jakevdp.github.io/PythonDataScienceHandbook/

# %% [markdown]
# # Supplementary Material
#
# - A Whirlwind Tour of Python by JakeVanderPlas
#     - https://github.com/jakevdp/WhirlwindTourOfPython
# - Data Science from Scratch by Joel Grus

# %% [markdown]
# # Software
#
# - You should install the following:
#     - An Anaconda distribution, either:
#         - Miniconda
#         - Anaconda
#         - https://www.anaconda.com
# - Any of the packages included with Anaconda can be manually installed on top of Miniconda via the terminal:
#
#     `[~]$ conda install numpy pandas scikit-learn matplotlib seaborn jupyter `

# %% [markdown]
# # IPython
#
# - "A tool for the entire lifecycle of research computing"
# - Python is the engine
# - IPython is the interactive control panel
# - Jupyter Notebooks closely linked
# - Focus on using Python effectively for interactive *scientific* and *data-intensive computing*.
# - Launch in a terminal via the following command: `ipython`

# %% [markdown]
# # Jupyter Notebooks
#
# - Browser-based graphical user interface to IPython shell
# - *formatted* __text__
# - Static and dynamic visualisations
# - Mathematical equations
# - Javascript widgets
# - Can be saved and shared simply to let other people execute and understand your code
# - Run the kernel via the shell command: `jupyter notebook`

# %% [markdown]
# # Help and Documentation in IPython
#
# - Independently understanding the code that you're writing is an important skill to pick up
# - Where to find help?
# - Being an effective practitioner of data science is __less__ about memorising all tools and commands and __more__ about learning to effectively finding the information that you don't know.
# - Common questions IPython can answer in a few keystrokes:
#     - How do I call this function?
#     - What does the source code look like?
#     - What is in the package I've imported?
# - Use `?` to explore documentation.
# - Use `??` to explore source code.
# - Press `tab` to auto-complete the code that you're writing.

# %%
?

# %%
len?

# %%
L = [1,2,3]
L?

# %%
def square(a):
    """Return the square of a."""
    return a ** 2

# %%
square?

# %%
square??

# %%
'''N.B Delete <TAB> and press the tab key. This won't run otherwise Ensure you havent deleted the . '''
L.<TAB>

# %% [markdown]
# # Tab-Completion
#
# - Every Python object has various attributes and methods associated with it.
# - Python can return a list of these using tab-completion.
# - To narrow down the list, type the first character or characters of the name, then press tab.
# - With a single option, Tab will auto-complete the code for you.
# - Tab-completion can also be used when importing objects from packages.
# - Beyond this we can also wildcard match using `*`

# %%
import antigravity

# %%
*Warning?

# %% [markdown]
# # Keyboard Shortcuts in the IPython Shell (not JNB)
#
# - You're proabably familiar with Cmd-C and Cmd-V (Ctrl-C or Ctrl-V)
# - Super useful for quickly performing certain commands.
# - `Ctrl-a` moves cursor to start of line.
# - `Ctrl-e` moves cursor to start of line
# - `Ctrl-k` cuts text from cursor to end of line
# - `Up arrow key` accesses previous command in history
# - `Down arrow key` accesses next command in history
# - `Ctrl-l` clears terminal screen
# - `Ctrl-c` interrupts current command from running
# - `Ctrl-d` exits IPython session
